# %%
import msticpy as mp

# %%
prov: mp.QueryProvider = mp.QueryProvider("LogAnalytics")

# %%
prov.connect(
    cluster="zsocngsadxfollew1adx01",
    database="AXA"
)
# Out:
# Attempting connection to Key Vault using cli credentials...
# done<br>
# connected

# %%
data = prov.Azure.list_aad_signins_for_account(cache_path="/home/azureuser/msticpy/test_cache.ipynb")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TenantId</th>
#       <th>SourceSystem</th>
#       <th>TimeGenerated</th>
#       <th>ResourceId</th>
#       <th>OperationName</th>
#       <th>OperationVersion</th>
#       <th>Category</th>
#       <th>ResultType</th>
#       <th>ResultSignature</th>
#       <th>ResultDescription</th>
#       <th>...</th>
#       <th>ResourceTenantId</th>
#       <th>HomeTenantId</th>
#       <th>UniqueTokenIdentifier</th>
#       <th>SessionLifetimePolicies</th>
#       <th>AutonomousSystemNumber</th>
#       <th>AuthenticationProtocol</th>
#       <th>CrossTenantAccessType</th>
# ...

# %%
data
# Out:
#                                   TenantId SourceSystem  \
# 0     16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 1     16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 2     16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 3     16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 4     16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# ...                                    ...          ...
# 1910  16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 1911  16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 1912  16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 1913  16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
# 1914  16b93757-aba0-41a6-886d-6ef95c755e76     Azure AD
#
#                         TimeGenerated  \
# 0    2024-02-28 09:52:34.633771+00:00
# 1    2024-02-28 09:53:36.764430+00:00
# 2    2024-02-28 09:54:28.251880+00:00
# 3    2024-02-28 09:55:15.628636+00:00
# 4    2024-02-28 09:56:52.007838+00:00
# ...                               ...
# ...
